# %%
from flipper_training.train_config import train_config

# %%
from omegaconf import OmegaConf

# %%
OmegaConf.create(train_config)
# Out:
# ---------------------------------------------------------------------------
# UnsupportedValueType                      Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 OmegaConf.create(train_config)
#
# File ~/.venv/lib/python3.12/site-packages/omegaconf/omegaconf.py:178, in OmegaConf.create(obj, parent, flags)
#     172 @staticmethod
#     173 def create(  # noqa F811
#     174     obj: Any = _DEFAULT_MARKER_,
#     175     parent: Optional[BaseContainer] = None,
#     176     flags: Optional[Dict[str, bool]] = None,
#     177 ) -> Union[DictConfig, ListConfig]:
# --> 178     return OmegaConf._create_impl(
#     179         obj=obj,
#     180         parent=parent,
#     181         flags=flags,
#     182     )
#
# File ~/.venv/lib/python3.12/site-packages/omegaconf/omegaconf.py:900, in OmegaConf._create_impl(obj, parent, flags)
#     896                 raise ValidationError(
#     897                     f"Object of unsupported type: '{type(obj).__name__}'"
#     898                 )
#     899 except OmegaConfBaseException as e:
# --> 900     format_and_raise(node=None, key=None, value=None, msg=str(e), cause=e)
#     901     assert False
#
# File ~/.venv/lib/python3.12/site-packages/omegaconf/_utils.py:819, in format_and_raise(node, key, value, msg, cause, type_override)
#     817         ex = type_override(str(cause))
#     818         ex.__dict__ = copy.deepcopy(cause.__dict__)
# --> 819     _raise(ex, cause)
#     821 object_type: Optional[Type[Any]]
#     822 object_type_str: Optional[str] = None
#
# File ~/.venv/lib/python3.12/site-packages/omegaconf/_utils.py:797, in _raise(ex, cause)
#     795 else:
#     796     ex.__cause__ = None
# --> 797 raise ex.with_traceback(sys.exc_info()[2])
#
# File ~/.venv/lib/python3.12/site-packages/omegaconf/omegaconf.py:861, in OmegaConf._create_impl(obj, parent, flags)
#     859         obj_type = OmegaConf.get_type(obj)
#     860         key_type, element_type = get_dict_key_value_types(obj_type)
# --> 861         return DictConfig(
#     862             content=obj,
#     863             parent=parent,
#     864             key_type=key_type,
#     865             element_type=element_type,
#     866             flags=flags,
#     867         )
#     868 elif is_primitive_list(obj) or OmegaConf.is_list(obj):
#     869     if isinstance(obj, ListConfig):
#
# File ~/.venv/lib/python3.12/site-packages/omegaconf/dictconfig.py:111, in DictConfig.__init__(self, content, key, parent, ref_type, key_type, element_type, is_optional, flags)
#     109         self._set_value(content, flags=flags)
#     110 except Exception as ex:
# --> 111     format_and_raise(node=None, key=key, value=None, cause=ex, msg=str(ex))
#
# File ~/.venv/lib/python3.12/site-packages/omegaconf/_utils.py:819, in format_and_raise(node, key, value, msg, cause, type_override)
#     817         ex = type_override(str(cause))
#     818         ex.__dict__ = copy.deepcopy(cause.__dict__)
# --> 819     _raise(ex, cause)
#     821 object_type: Optional[Type[Any]]
#     822 object_type_str: Optional[str] = None
#
# File ~/.venv/lib/python3.12/site-packages/omegaconf/_utils.py:797, in _raise(ex, cause)
#     795 else:
#     796     ex.__cause__ = None
# --> 797 raise ex.with_traceback(sys.exc_info()[2])
#
# File ~/.venv/lib/python3.12/site-packages/omegaconf/dictconfig.py:109, in DictConfig.__init__(self, content, key, parent, ref_type, key_type, element_type, is_optional, flags)
#     107             metadata.key_type = key_type
#     108             self.__dict__["_metadata"] = metadata
# --> 109         self._set_value(content, flags=flags)
#     110 except Exception as ex:
#     111     format_and_raise(node=None, key=key, value=None, cause=ex, msg=str(ex))
#
# File ~/.venv/lib/python3.12/site-packages/omegaconf/dictconfig.py:647, in DictConfig._set_value(self, value, flags)
#     645 except Exception as e:
#     646     self.__dict__["_content"] = previous_content
# --> 647     raise e
#
# File ~/.venv/lib/python3.12/site-packages/omegaconf/dictconfig.py:644, in DictConfig._set_value(self, value, flags)
#     642 try:
#     643     previous_content = self.__dict__["_content"]
# --> 644     self._set_value_impl(value, flags)
#     645 except Exception as e:
#     646     self.__dict__["_content"] = previous_content
#
# File ~/.venv/lib/python3.12/site-packages/omegaconf/dictconfig.py:690, in DictConfig._set_value_impl(self, value, flags)
#     688     with flag_override(self, ["struct", "readonly"], False):
#     689         for k, v in value.items():
# --> 690             self.__setitem__(k, v)
#     691     self._metadata.object_type = dict
#     693 else:  # pragma: no cover
#
# File ~/.venv/lib/python3.12/site-packages/omegaconf/dictconfig.py:314, in DictConfig.__setitem__(self, key, value)
#     310     self._format_and_raise(
#     311         key=key, value=value, type_override=ConfigKeyError, cause=e
#     312     )
#     313 except Exception as e:
# --> 314     self._format_and_raise(key=key, value=value, cause=e)
#
# File ~/.venv/lib/python3.12/site-packages/omegaconf/base.py:231, in Node._format_and_raise(self, key, value, cause, msg, type_override)
#     223 def _format_and_raise(
#     224     self,
#     225     key: Any,
#    (...)
#     229     type_override: Any = None,
#     230 ) -> None:
# --> 231     format_and_raise(
#     232         node=self,
#     233         key=key,
#     234         value=value,
#     235         msg=str(cause) if msg is None else msg,
#     236         cause=cause,
#     237         type_override=type_override,
#     238     )
#     239     assert False
#
# File ~/.venv/lib/python3.12/site-packages/omegaconf/_utils.py:819, in format_and_raise(node, key, value, msg, cause, type_override)
#     817         ex = type_override(str(cause))
#     818         ex.__dict__ = copy.deepcopy(cause.__dict__)
# --> 819     _raise(ex, cause)
#     821 object_type: Optional[Type[Any]]
#     822 object_type_str: Optional[str] = None
#
# File ~/.venv/lib/python3.12/site-packages/omegaconf/_utils.py:797, in _raise(ex, cause)
#     795 else:
#     796     ex.__cause__ = None
# --> 797 raise ex.with_traceback(sys.exc_info()[2])
#
# File ~/.venv/lib/python3.12/site-packages/omegaconf/dictconfig.py:308, in DictConfig.__setitem__(self, key, value)
#     306 def __setitem__(self, key: DictKeyType, value: Any) -> None:
#     307     try:
# --> 308         self.__set_impl(key=key, value=value)
#     309     except AttributeError as e:
#     310         self._format_and_raise(
#     311             key=key, value=value, type_override=ConfigKeyError, cause=e
#     312         )
#
# File ~/.venv/lib/python3.12/site-packages/omegaconf/dictconfig.py:318, in DictConfig.__set_impl(self, key, value)
#     316 def __set_impl(self, key: DictKeyType, value: Any) -> None:
#     317     key = self._validate_and_normalize_key(key)
# --> 318     self._set_item_impl(key, value)
#
# File ~/.venv/lib/python3.12/site-packages/omegaconf/basecontainer.py:620, in BaseContainer._set_item_impl(self, key, value)
#     618         assign(key, value)
#     619 else:
# --> 620     self._wrap_value_and_set(key, value, target_type_hint)
#
# File ~/.venv/lib/python3.12/site-packages/omegaconf/basecontainer.py:636, in BaseContainer._wrap_value_and_set(self, key, val, type_hint)
#     628     wrapped = _maybe_wrap(
#     629         ref_type=ref_type,
#     630         key=key,
#    (...)
#     633         parent=self,
#     634     )
#     635 except ValidationError as e:
# --> 636     self._format_and_raise(key=key, value=val, cause=e)
#     637 self.__dict__["_content"][key] = wrapped
#
# File ~/.venv/lib/python3.12/site-packages/omegaconf/base.py:231, in Node._format_and_raise(self, key, value, cause, msg, type_override)
#     223 def _format_and_raise(
#     224     self,
#     225     key: Any,
#    (...)
#     229     type_override: Any = None,
#     230 ) -> None:
# --> 231     format_and_raise(
#     232         node=self,
#     233         key=key,
#     234         value=value,
#     235         msg=str(cause) if msg is None else msg,
#     236         cause=cause,
#     237         type_override=type_override,
#     238     )
#     239     assert False
#
# File ~/.venv/lib/python3.12/site-packages/omegaconf/_utils.py:899, in format_and_raise(node, key, value, msg, cause, type_override)
#     896     ex.ref_type = ref_type
#     897     ex.ref_type_str = ref_type_str
# --> 899 _raise(ex, cause)
#
# File ~/.venv/lib/python3.12/site-packages/omegaconf/_utils.py:797, in _raise(ex, cause)
#     795 else:
#     796     ex.__cause__ = None
# --> 797 raise ex.with_traceback(sys.exc_info()[2])
#
# File ~/.venv/lib/python3.12/site-packages/omegaconf/basecontainer.py:628, in BaseContainer._wrap_value_and_set(self, key, val, type_hint)
#     625 is_optional, ref_type = _resolve_optional(type_hint)
#     627 try:
# --> 628     wrapped = _maybe_wrap(
#     629         ref_type=ref_type,
#     630         key=key,
#     631         value=val,
#     632         is_optional=is_optional,
#     633         parent=self,
#     634     )
#     635 except ValidationError as e:
#     636     self._format_and_raise(key=key, value=val, cause=e)
#
# File ~/.venv/lib/python3.12/site-packages/omegaconf/omegaconf.py:1105, in _maybe_wrap(ref_type, key, value, is_optional, parent)
#    1103     return value
#    1104 else:
# -> 1105     return _node_wrap(
#    1106         ref_type=ref_type,
#    1107         parent=parent,
#    1108         is_optional=is_optional,
#    1109         value=value,
#    1110         key=key,
#    1111     )
#
# File ~/.venv/lib/python3.12/site-packages/omegaconf/omegaconf.py:1045, in _node_wrap(parent, is_optional, value, key, ref_type)
#    1037     node = UnionNode(
#    1038         content=value,
#    1039         ref_type=ref_type,
#    (...)
#    1042         parent=parent,
#    1043     )
#    1044 elif ref_type == Any or ref_type is None:
# -> 1045     node = AnyNode(value=value, key=key, parent=parent)
#    1046 elif isinstance(ref_type, type) and issubclass(ref_type, Enum):
#    1047     node = EnumNode(
#    1048         enum_type=ref_type,
#    1049         value=value,
#    (...)
#    1052         is_optional=is_optional,
#    1053     )
#
# File ~/.venv/lib/python3.12/site-packages/omegaconf/nodes.py:135, in AnyNode.__init__(self, value, key, parent, flags)
#     128 def __init__(
#     129     self,
#     130     value: Any = None,
#    (...)
#     133     flags: Optional[Dict[str, bool]] = None,
#     134 ):
# --> 135     super().__init__(
#     136         parent=parent,
#     137         value=value,
#     138         metadata=Metadata(
#     139             ref_type=Any, object_type=None, key=key, optional=True, flags=flags
#     140         ),
#     141     )
#
# File ~/.venv/lib/python3.12/site-packages/omegaconf/nodes.py:29, in ValueNode.__init__(self, parent, value, metadata)
#      27 super().__init__(parent=parent, metadata=metadata)
#      28 with read_write(self):
# ---> 29     self._set_value(value)
#
# File ~/.venv/lib/python3.12/site-packages/omegaconf/nodes.py:46, in ValueNode._set_value(self, value, flags)
#      44     self._val = value
#      45 else:
# ---> 46     self._val = self.validate_and_convert(value)
#
# File ~/.venv/lib/python3.12/site-packages/omegaconf/nodes.py:76, in ValueNode.validate_and_convert(self, value)
#      74     return value
#      75 else:
# ---> 76     return self._validate_and_convert_impl(value)
#
# File ~/.venv/lib/python3.12/site-packages/omegaconf/nodes.py:154, in AnyNode._validate_and_convert_impl(self, value)
#     150 if self._get_flag(
#     151     "allow_objects"
#     152 ) is not True and not is_primitive_type_annotation(value):
#     153     t = get_type_of(value)
# --> 154     raise UnsupportedValueType(
#     155         f"Value '{t.__name__}' is not a supported primitive type"
#     156     )
#     157 return value
#
# UnsupportedValueType: Value 'Adam' is not a supported primitive type
#     full_key: optimizer
#     object_type=dict
