# %%
# %load_ext autoreload
# %autoreload 2

# %%
from flipper_training.heightmaps.trunks import TrunkHeightmapGenerator

# %%
gen = TrunkHeightmapGenerator()

# %%
n = 2
x, y, z, sides = gen(0.05, 3.2, n)

# %%
from flipper_training.vis.static_vis import plot_heightmap_3d

# %%
for i in range(n):
    print(f"Plotting heightmap {i}")
    plot_heightmap_3d(x[i], y[i], z[i]).show()
# Out:
# Plotting heightmap 0
# Plotting heightmap 1

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 2, figsize=(10, 5))
ax[0].imshow(sides["trunk_sides"][0])
ax[1].imshow(z[0])
